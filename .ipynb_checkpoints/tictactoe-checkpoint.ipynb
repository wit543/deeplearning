# %%
from __future__ import print_function
# %env KERAS_BACKEND=tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense
from tictactoe import TicTacToeGame
import random
import numpy as np
# Out:
# env: KERAS_BACKEND=tensorflow
# C:\Users\wit543\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
game = TicTacToeGame()

def state_to_number( state):
    return np.array(list(map(int,(state.replace('X','1').replace('O','2').replace(' ','0'))))).reshape((1,9))

def get_move(idx):
#     print(game.state[:idx-1])
#     print( game.state[idx:])
    return game.state[:idx-1] + game.player + game.state[idx:]



# Agent 1
model1 = Sequential()
model1.add(Dense(32, input_shape=(9,)))
model1.add(Dense(9, activation='softmax'))
model1.compile(loss=keras.losses.categorical_crossentropy, # loss function use for calculate the amount of error
              optimizer=keras.optimizers.Adadelta(), # optimizer for determine how to adjusting the error
              metrics=['accuracy'])

# Agent 2
model2 = Sequential()
model2.add(Dense(32, input_shape=(9,)))
model2.add(Dense(9, activation='softmax'))
model2.compile(loss=keras.losses.categorical_crossentropy, # loss function use for calculate the amount of error
              optimizer=keras.optimizers.Adadelta(), # optimizer for determine how to adjusting the error
              metrics=['accuracy'])
envs = []
actions = []
epochs = 100
for epoch in range(epochs):
    while game.playable():
#         print(game.player, "turn")
#         game.print_board()
#         print(game.state)
#         print(state_to_number(game.state))
        allowed_moves = [i+1 for i in range(9) if game.state[i] == ' ']
        if game.player == 'X':
            move = model1.predict(state_to_number(game.state))
#             print(move)
            m = max(move[0])
            array = [i for i, j in enumerate(move[0]) if j == m]
            move = array[0] +1
#             print(move)
            allowed_moves = [i+1 for i in range(9) if game.state[i] == ' ']
            if move  not in array:
                move = random.choice([i+1 for i in range(9) if game.state[i] == ' '])
            game.make_move(move)
        else:
#             move = model2.predict(state_to_number(game.state))
            move = random.choice([i+1 for i in range(9) if game.state[i] == ' '])
            game.make_move(move)
        actions.append(move)
        envs.append(state_to_number(game.state))
#     print(game.winner)
#     print(actions)
    actions = keras.utils.to_categorical(np.array(actions)-1, 9)
    if game.winner == 'X':
#         print(np.array(envs).reshape(7,9))
#         print(actions)
        model1.fit(np.array(envs).reshape(len(envs),9),np.array(actions),batch_size=len(envs))
    else:
        model2.fit(np.array(envs).reshape(len(envs),9),np.array(actions),batch_size=len(envs))
    envs = []
    actions = []
    game = TicTacToeGame()
# Out:
# Epoch 1/1
# 7/7 [==============================] - 0s 28ms/step - loss: 2.2431 - acc: 0.4286
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.8612 - acc: 0.2222
# Epoch 1/1
# 8/8 [==============================] - 0s 29ms/step - loss: 2.2479 - acc: 0.1250
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.2333 - acc: 0.1250
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.1899 - acc: 0.2222
# Epoch 1/1
# 5/5 [==============================] - 0s 197us/step - loss: 2.1010 - acc: 0.2000
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.2922 - acc: 0.3333
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 2.7138 - acc: 0.1429
# Epoch 1/1
# 6/6 [==============================] - 0s 334us/step - loss: 2.4509 - acc: 0.3333
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 2.3181 - acc: 0.3333
# Epoch 1/1
# 6/6 [==============================] - 0s 250us/step - loss: 2.5240 - acc: 0.0000e+00
# Epoch 1/1
# 8/8 [==============================] - 0s 187us/step - loss: 2.5528 - acc: 0.1250
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 1.9796 - acc: 0.4286
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 2.2687 - acc: 0.3333
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.1211 - acc: 0.1250
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 2.3925 - acc: 0.2857
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 2.3919 - acc: 0.1667
# Epoch 1/1
# 7/7 [==============================] - 0s 215us/step - loss: 2.2416 - acc: 0.1429
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.3729 - acc: 0.1250
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.4047 - acc: 0.1250
# Epoch 1/1
# 6/6 [==============================] - 0s 250us/step - loss: 2.5313 - acc: 0.1667
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 2.1670 - acc: 0.1429
# Epoch 1/1
# 8/8 [==============================] - 0s 124us/step - loss: 2.1140 - acc: 0.1250
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 2.3372 - acc: 0.5000
# Epoch 1/1
# 5/5 [==============================] - 0s 300us/step - loss: 2.1561 - acc: 0.2000
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.5504 - acc: 0.2222
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 1.9429 - acc: 0.1429
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.3329 - acc: 0.1111
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.2465 - acc: 0.3333
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.0327 - acc: 0.3333
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.4971 - acc: 0.2222
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.0610 - acc: 0.3333
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 2.1246 - acc: 0.1429
# Epoch 1/1
# 5/5 [==============================] - 0s 300us/step - loss: 1.9839 - acc: 0.2000
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.4509 - acc: 0.1111
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.1853 - acc: 0.1250
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.3493 - acc: 0.2222
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.1471 - acc: 0.2500
# Epoch 1/1
# 8/8 [==============================] - 0s 250us/step - loss: 2.2473 - acc: 0.3750
# Epoch 1/1
# 5/5 [==============================] - 0s 300us/step - loss: 2.1209 - acc: 0.2000
# Epoch 1/1
# 5/5 [==============================] - 0s 200us/step - loss: 1.8150 - acc: 0.6000
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 1.9392 - acc: 0.5000
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 2.2289 - acc: 0.1429
# Epoch 1/1
# 7/7 [==============================] - 0s 215us/step - loss: 2.6683 - acc: 0.1429
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.1353 - acc: 0.3333
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 2.1883 - acc: 0.2857
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.3135 - acc: 0.0000e+00
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.3224 - acc: 0.2500
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.3064 - acc: 0.1250
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 1.8932 - acc: 0.2857
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.2610 - acc: 0.2222
# Epoch 1/1
# 6/6 [==============================] - 0s 250us/step - loss: 1.8725 - acc: 0.1667
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.1757 - acc: 0.3333
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.3965 - acc: 0.0000e+00
# Epoch 1/1
# 5/5 [==============================] - 0s 200us/step - loss: 1.8086 - acc: 0.6000
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.2974 - acc: 0.2222
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.3966 - acc: 0.2222
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.2699 - acc: 0.1111
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.1691 - acc: 0.2500
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.3019 - acc: 0.1111
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.2104 - acc: 0.1250
# Epoch 1/1
# 6/6 [==============================] - 0s 333us/step - loss: 1.9575 - acc: 0.5000
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.2328 - acc: 0.1111
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.1735 - acc: 0.1111
# Epoch 1/1
# 5/5 [==============================] - 0s 200us/step - loss: 1.9182 - acc: 0.4000
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.2716 - acc: 0.2500
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 1.9803 - acc: 0.2857
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.4947 - acc: 0.2500
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.2008 - acc: 0.0000e+00
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.3291 - acc: 0.1111
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 1.9935 - acc: 0.2857
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.1573 - acc: 0.1111
# Epoch 1/1
# 5/5 [==============================] - 0s 200us/step - loss: 2.0572 - acc: 0.2000
# Epoch 1/1
# 5/5 [==============================] - 0s 200us/step - loss: 1.7694 - acc: 0.2000
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.4932 - acc: 0.1111
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.3667 - acc: 0.1250
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 2.2229 - acc: 0.1429
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.1997 - acc: 0.3333
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.1898 - acc: 0.1250
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.2326 - acc: 0.3750
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 2.0651 - acc: 0.4286
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.1943 - acc: 0.4444
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 2.1019 - acc: 0.1429
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 2.3036 - acc: 0.1667
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.0320 - acc: 0.4444
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.2678 - acc: 0.2500
# Epoch 1/1
# 8/8 [==============================] - 0s 125us/step - loss: 2.1809 - acc: 0.3750
# Epoch 1/1
# 9/9 [==============================] - 0s 167us/step - loss: 2.2546 - acc: 0.1111
# Epoch 1/1
# 8/8 [==============================] - 0s 188us/step - loss: 2.2482 - acc: 0.2500
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.2629 - acc: 0.0000e+00
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.1034 - acc: 0.1111
# Epoch 1/1
# 5/5 [==============================] - 0s 300us/step - loss: 2.3269 - acc: 0.4000
# Epoch 1/1
# 7/7 [==============================] - 0s 143us/step - loss: 2.0862 - acc: 0.2857
# Epoch 1/1
# 5/5 [==============================] - 0s 300us/step - loss: 1.8857 - acc: 0.4000
# Epoch 1/1
# 6/6 [==============================] - 0s 250us/step - loss: 2.4356 - acc: 0.1667
# Epoch 1/1
# 5/5 [==============================] - 0s 300us/step - loss: 1.9829 - acc: 0.2000
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 2.2243 - acc: 0.0000e+00
# Epoch 1/1
# 6/6 [==============================] - 0s 167us/step - loss: 2.3401 - acc: 0.1667
# Epoch 1/1
# 9/9 [==============================] - 0s 111us/step - loss: 2.3142 - acc: 0.1111
# Epoch 1/1
# 7/7 [==============================] - 0s 214us/step - loss: 2.1217 - acc: 0.0000e+00

# %%
  while game.playable():
        allowed_moves = [i+1 for i in range(9) if game.state[i] == ' ']
        if game.player == 'X':
            move = model1.predict(state_to_number(game.state))
            m = max(move[0])
            array = [i for i, j in enumerate(move[0]) if j == m]
            move = array[0] +1
            allowed_moves = [i+1 for i in range(9) if game.state[i] == ' ']
            if move  not in array:
                move = random.choice([i+1 for i in range(9) if game.state[i] == ' '])
            game.make_move(move)
        else:
